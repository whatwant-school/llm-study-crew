# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "Qwen/Qwen3-4B"

# load the tokenizer and the model
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    device_map="auto"
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/9.68k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/726 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/32.8k [00:00<?, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/3.99G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/3.96G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/99.6M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]

# %%
# prepare the model input
prompt = "LLM에 대해서 설명해줘. 대답은 한글로 해줘"
messages = [
    {"role": "user", "content": prompt}
]
text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True,
    enable_thinking=True # Switches between thinking and non-thinking modes. Default is True.
)
model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

# conduct text completion
generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=32768
)
output_ids = generated_ids[0][len(model_inputs.input_ids[0]):].tolist()

# %%
# parsing thinking content
try:
    # rindex finding 151668 (</think>)
    index = len(output_ids) - output_ids[::-1].index(151668)
except ValueError:
    index = 0

thinking_content = tokenizer.decode(output_ids[:index], skip_special_tokens=True).strip("\n")
content = tokenizer.decode(output_ids[index:], skip_special_tokens=True).strip("\n")

print("thinking content:", thinking_content)
print("content:", content)
# Out:
# thinking content: <think>
# Okay, the user asked me to explain LLMs in Korean. Let me start by recalling what LLM stands for. It's Large Language Model. I need to make sure I explain it clearly, step by step.
#
# First, I should define what an LLM is. Maybe start with the basics: it's a type of AI model that understands and generates human language. Then mention that it's based on deep learning, using neural networks. I should explain the key components, like training data, the architecture (maybe mention transformer models), and how they process text.
#
# I should also highlight the applications of LLMs, such as answering questions, writing articles, coding, etc. It's important to note that they're trained on vast amounts of text data, which allows them to understand context and generate coherent responses.
#
# Wait, the user might not be familiar with technical terms like transformers or neural networks. I should explain those in simple terms. Maybe compare them to something more relatable, like a brain or a system that processes information.
#
# Also, mention the difference between LLMs and other AI models. Maybe say that LLMs are more specialized in language tasks. Talk about the size of the models, like how they have billions of parameters, which contributes to their ability to handle complex tasks.
#
# Don't forget to mention some examples of LLMs, like GPT-3, BERT, or others. But maybe keep it general unless the user asks for specific examples.
#
# I should also touch on the challenges or limitations, such as the need for large computational resources, potential biases in training data, and the fact that they might not always be accurate.
#
# Make sure the explanation is structured logically, starting from what LLMs are, how they work, their applications, and their limitations. Keep the language simple and avoid jargon as much as possible. Check that the answer is in Korean and flows naturally.
# </think>
# content: LLM은 **대규모 언어 모델**(Large Language Model)을 의미합니다. 이는 자연어를 이해하고 생성하는 인공지능(AI) 모델로, 인간과 유사한 언어 처리 능력을 가집니다. LLM은 **심층 학습**(Deep Learning) 기술을 기반으로 하며, 텍스트 데이터를 학습해 문맥을 이해하고, 질문에 답변하거나 글을 작성하는 등 다양한 언어 작업을 수행합니다.
#
# ### LLM의 핵심 특징
# 1. **대규모 데이터 학습**
#    LLM은 수십억 개의 텍스트 데이터(웹 페이지, 책, 문서 등)를 학습해 언어 패턴과 의미를 학습합니다. 이로 인해 다양한 주제에 대한 이해가 가능해집니다.
#
# 2. **트랜스포머 아키텍처**
#    LLM은 **트랜스포머**(Transformer)라는 신경망 구조를 사용합니다. 이 구조는 문장 내 단어 간의 관계를 효율적으로 처리할 수 있도록 설계되어, 문맥 이해와 문장 생성에 강점이 있습니다.
#
# 3. **문맥 이해 능력**
#    LLM은 단순한 단어 조합을 넘어, 문장의 전체적인 의미를 파악해 자연스러운 대화나 글을 생성할 수 있습니다. 예를 들어, "오늘 날씨가 좋아요"라는 문장은 "좋아요"가 어떤 감정을 표현하는지 문맥에서 유추할 수 있습니다.
#
# 4. **다양한 작업 지원**
#    - 질문에 답변하기
#    - 글쓰기(소설, 기사, 이메일 등)
#    - 코드 작성 및 수정
#    - 번역, 요약, 대화 등
#
# ### LLM의 예시
# - **GPT** (OpenAI)
# - **BERT** (Google)
# - **T5** (Google)
# - **Llama** (Meta)
# - **Qwen** (通义千问)
#
# ### 한계점
# - **계산 리소스 필요**
#   대규모 모델은 많은 데이터와 계산력을 필요로 하기 때문에, 훈련과 사용에 비용이 많이 듭니다.
# - **데이터 편향성**
#   학습된 데이터에 편향이 포함될 수 있어, 답변이 불안정하거나 오류가 발생할 수 있습니다.
# - **정확도 제한**
#   인간의 지식이나 문맥을 완전히 이해하지 못할 때, 답변이 부정확할 수 있습니다.
#
# ### 요약
# LLM은 인간과 유사한 언어를 이해하고 생성하는 AI로, 다양한 작업에 활용됩니다. 하지만 대규모 데이터와 강력한 계산력이 필요하며, 사용 시 주의가 필요합니다. LLM은 AI의 발전 중 중요한 역할을 하고 있으며, 앞으로 더 많은 응용이 기대됩니다.

# %%
# prepare the model input
prompt = "LLM에 대해서 설명해줘. 대답은 한글로 해줘"
messages = [
    {"role": "user", "content": prompt}
]
text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True,
    enable_thinking=False
)
model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

# conduct text completion
generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=32768
)
output_ids = generated_ids[0][len(model_inputs.input_ids[0]):].tolist()

# %%
# parsing thinking content
try:
    # rindex finding 151668 (</think>)
    index = len(output_ids) - output_ids[::-1].index(151668)
except ValueError:
    index = 0

thinking_content = tokenizer.decode(output_ids[:index], skip_special_tokens=True).strip("\n")
content = tokenizer.decode(output_ids[index:], skip_special_tokens=True).strip("\n")

print("thinking content:", thinking_content)
print("content:", content)
# Out:
# thinking content:
# content: LLM은 **Large Language Model**의 약자로, 매우 큰 규모의 언어 모델을 의미합니다. LLM은 자연어를 이해하고 생성할 수 있는 인공지능 모델로, 텍스트 생성, 대화, 요약, 번역, 질문 답변 등 다양한 작업을 수행할 수 있습니다.
#
# LLM은 일반적으로 매우 많은 데이터를 학습하여 언어 패턴을 학습하고, 이를 기반으로 새로운 문장을 생성하거나 기존 문장을 이해하는 능력을 갖춥니다. 예를 들어, "오늘 날씨가 좋아요"라는 문장을 입력하면, LLM은 그 문장의 의미를 이해하고, 관련된 문장을 생성하거나 답변을 제공할 수 있습니다.
#
# LLM은 주로 다음과 같은 특징을 가지고 있습니다:
#
# 1. **대규모 데이터 학습**: 수십억 개의 단어를 학습하여 언어 모델을 구축합니다.
# 2. **유연한 사용**: 다양한 작업에 사용 가능합니다.
# 3. **대화형 인터페이스**: 대화형 인터페이스를 통해 사용자와 대화할 수 있습니다.
# 4. **다국어 지원**: 다양한 언어를 지원하여 글로벌 사용이 가능합니다.
#
# LLM은 기존의 작은 언어 모델과 비교해 더 높은 정확도와 유연성을 가지고 있으며, 다양한 산업 분야에서 활용되고 있습니다. 예를 들어, 고객 지원, 콘텐츠 생성, 의료, 교육 등 다양한 분야에서 사용됩니다.
